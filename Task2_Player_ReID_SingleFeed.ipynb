# %%
import cv2
import numpy as np
import torch
from matplotlib import pyplot as plt
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort
from IPython.display import display
import ipywidgets as widgets

# %%
model = YOLO("yolov11.pt")

# %%
tracker = DeepSort(max_age=30, n_init=3, nn_budget=100)

# %%
video_path = '15sec_input_720p.mp4'
cap = cv2.VideoCapture(video_path)

frames = []
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run inference with YOLO
    results = model(frame)
    detections = results[0].boxes.xyxy.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()

    filtered_dets = []
    for det, cls in zip(detections, classes):
        if int(cls) == 0:  # Class 0 = player
            x1, y1, x2, y2 = map(int, det[:4])
            w, h = x2 - x1, y2 - y1
            conf = float(det[4]) if len(det) > 4 else 0.8
            filtered_dets.append(([x1, y1, w, h], conf, 'player'))

    # Update Deep SORT
    tracks = tracker.update_tracks(filtered_dets, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue
        track_id = track.track_id
        x1, y1, x2, y2 = map(int, track.to_ltrb())
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f'ID: {track_id}', (x1, y1 - 12), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    frame_count += 1

cap.release()
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 1868.0ms
# Speed: 4.3ms preprocess, 1868.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 2 referees, 1739.9ms
# Speed: 9.2ms preprocess, 1739.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1743.2ms
# Speed: 4.6ms preprocess, 1743.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1751.9ms
# Speed: 5.5ms preprocess, 1751.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1756.5ms
# Speed: 5.7ms preprocess, 1756.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1752.8ms
# Speed: 4.5ms preprocess, 1752.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1752.1ms
# Speed: 4.5ms preprocess, 1752.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1714.0ms
# Speed: 5.9ms preprocess, 1714.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 1748.5ms
# Speed: 6.3ms preprocess, 1748.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1738.7ms
# Speed: 3.8ms preprocess, 1738.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1748.2ms
# Speed: 4.6ms preprocess, 1748.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1753.9ms
# Speed: 4.1ms preprocess, 1753.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 1754.5ms
# Speed: 3.6ms preprocess, 1754.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1678.3ms
# Speed: 4.8ms preprocess, 1678.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1726.8ms
# Speed: 6.8ms preprocess, 1726.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 1726.1ms
# Speed: 4.1ms preprocess, 1726.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1817.2ms
# Speed: 6.4ms preprocess, 1817.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1656.3ms
# Speed: 11.1ms preprocess, 1656.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 1773.8ms
# Speed: 100.6ms preprocess, 1773.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 3074.6ms
# Speed: 7.6ms preprocess, 3074.6ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1975.7ms
# Speed: 7.1ms preprocess, 1975.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 1856.1ms
# Speed: 5.3ms preprocess, 1856.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1908.5ms
# Speed: 4.2ms preprocess, 1908.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1907.9ms
# Speed: 5.8ms preprocess, 1907.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 1684.0ms
# Speed: 2.8ms preprocess, 1684.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 1823.0ms
# Speed: 4.4ms preprocess, 1823.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 2560.3ms
# Speed: 5.2ms preprocess, 2560.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 2256.3ms
# Speed: 3.8ms preprocess, 2256.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 1734.5ms
# Speed: 6.4ms preprocess, 1734.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 2293.8ms
# Speed: 6.5ms preprocess, 2293.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 2 referees, 2121.5ms
# Speed: 5.1ms preprocess, 2121.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1922.3ms
# Speed: 5.1ms preprocess, 1922.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 
1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1865.1ms
# Speed: 5.5ms preprocess, 1865.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1756.4ms
# Speed: 5.0ms preprocess, 1756.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1799.9ms
# Speed: 5.0ms preprocess, 1799.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1759.4ms
# Speed: 5.1ms preprocess, 1759.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1783.7ms
# Speed: 5.5ms preprocess, 1783.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1752.7ms
# Speed: 4.5ms preprocess, 1752.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1792.4ms
# Speed: 5.0ms preprocess, 1792.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1760.1ms
# Speed: 5.4ms preprocess, 1760.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1745.5ms
# Speed: 5.2ms preprocess, 1745.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1725.8ms
# Speed: 6.8ms preprocess, 1725.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1798.6ms
# Speed: 5.5ms preprocess, 1798.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1901.4ms
# Speed: 5.5ms preprocess, 1901.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1866.7ms
# Speed: 5.7ms preprocess, 1866.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1769.0ms
# Speed: 4.4ms preprocess, 1769.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1792.7ms
# Speed: 7.0ms preprocess, 1792.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1768.3ms
# Speed: 4.0ms preprocess, 1768.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1740.3ms
# Speed: 5.2ms preprocess, 1740.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1751.1ms
# Speed: 4.2ms preprocess, 1751.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1782.2ms
# Speed: 4.4ms preprocess, 1782.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1818.2ms
# Speed: 4.2ms preprocess, 1818.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1783.5ms
# Speed: 5.5ms preprocess, 1783.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1711.9ms
# Speed: 4.3ms preprocess, 1711.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1814.4ms
# Speed: 4.6ms preprocess, 1814.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
player_counts = []

def count_players_in_frame(frame):
    # Count number of 'ID:' labels to estimate players
    count = 0
    hsv = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
    mask = cv2.inRange(hsv, (36, 25, 25), (86, 255,255))  # green box color range
    contours, _ = cv2.findContours(mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return len(contours)

for f in frames:
    player_counts.append(count_players_in_frame(f))

def view_frame_with_graph(index):
    fig, axs = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [4, 1]})

    # Show the frame
    axs[0].imshow(frames[index])
    axs[0].set_title(f"Frame {index} with Player IDs")
    axs[0].set_xlabel("X-axis (pixels)")
    axs[0].set_ylabel("Y-axis (pixels)")
    axs[0].axis('on')

    # Bar chart of players across frames
    axs[1].bar(range(len(player_counts)), player_counts, color='lightblue')
    axs[1].set_title("Number of Players Detected per Frame")
    axs[1].set_xlabel("Frame Index")
    axs[1].set_ylabel("Player Count")
    axs[1].axvline(x=index, color='red', linestyle='--', label='Current Frame')
    axs[1].legend()

    plt.tight_layout()
    plt.show()

slider = widgets.IntSlider(min=0, max=len(frames)-1, step=1, value=len(frames)//2, description='Frame')
widgets.interact(view_frame_with_graph, index=slider)
# Out:
# interactive(children=(IntSlider(value=187, description='Frame', max=374), Output()), _dom_classes=('widget-int…
# <function __main__.view_frame_with_graph(index)>

# %%
if frames:
    height, width = frames[0].shape[:2]
    out = cv2.VideoWriter('output_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), 30, (width, height))
    for f in frames:
        out.write(cv2.cvtColor(f, cv2.COLOR_RGB2BGR))
    out.release()
    print("✅ Output video saved as 'output_video.mp4'")
else:
    print("⚠️ No video to save.")
# Out:
# ✅ Output video saved as 'output_video.mp4'
